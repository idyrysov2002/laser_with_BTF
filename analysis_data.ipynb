# %%
from pathlib import Path
import numpy as np
from scripts.create_folder import create_date_folder
from scripts.read_from_txt import read_txt_xyz
from scripts.plot_and_save_xy import plot_and_save_xy
import matplotlib.pyplot as plt
from scripts.create_map_and_save import create_map_and_save
from scripts.get_OSC_data_from_txt import get_OSC_data_from_txt

def filter_map_osc():
    title='OSC'
    threshold_freq=600
    new_file_name=f'osc_mean_freq'
    save_folder=rf'Z:\data_for_laser_with_BTF\laser_with_btf_cir_SN_26736318_after_coupler_April-23-2026_time_18-02-14\maps\wavelength_1550nm'
    
    
           
    folder_path=rf'Z:\data_for_laser_with_BTF\laser_with_btf_cir_SN_26736318_after_coupler_April-23-2026_time_18-02-14\maps\wavelength_1550nm'
    file_name=rf'osc_mean_freq.txt'
    full_path=Path(folder_path)/file_name
    current_data, delay_data, freq_data =read_txt_xyz (full_path=full_path, header=1)
            
                    
    freq_arr = np.array(freq_data)
    # freq_mask= np.where(freq_arr > threshold_freq, np.nan, freq_arr)
    # freq_mask=np.array(freq_data)
    x_arr=[current_data, 'Current, mA']
    y_arr=[delay_data, 'Delay, ps']
    z_arr=[freq_arr, 'Frequency, GHz']
    create_map_and_save(
    x_arr=x_arr, 
    y_arr=y_arr, 
    z_arr=z_arr, 
    title=title, 
    folder_path=save_folder, 
    filename=new_file_name, 
    show_plot=True
    )
        
                
filter_map_osc()
# Out:
# Данные успешно сохранены в:Z:\data_for_laser_with_BTF\laser_with_btf_cir_SN_26736318_after_coupler_April-23-2026_time_18-02-14\maps\wavelength_1550nm\ff\osc_mean_freq.txt
#
# График сохранён: Z:\data_for_laser_with_BTF\laser_with_btf_cir_SN_26736318_after_coupler_April-23-2026_time_18-02-14\maps\wavelength_1550nm\ff\osc_mean_freq.png

# %%
slice_current(slice_current, current_arr, delay_arr, freq_arr)
